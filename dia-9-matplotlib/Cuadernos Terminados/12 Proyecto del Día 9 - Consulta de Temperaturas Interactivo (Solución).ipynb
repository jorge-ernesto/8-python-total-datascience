# %% [markdown]
# # Proyecto del Día 9: Consulta de Temperaturas Interactivo por Ciudad y Mes (solución)
#
# ## Objetivo
#
# El proyecto propuesto consistirá en la creación de un programa interactivo para la visualización de datos meteorológicos. Este programa permitirá a los usuarios visualizar los registros climáticos eligiendo el lugar y el més. El objetivo es aplicar los conceptos de creación de gráficos, personalización de estilos y combinarlo con las habilidades de desarrollo de programas con Python.
#
# ## Consigna
#
# 1. **Cargar un DataFrame** con los datos meteorológicos provistos en el archivo descargable de esta lección.
# 2. Asegúrate de que las **fechas** estén en el **formato correcto** para su manipulación posterior.
# 3. Crea un programa (una función o un conjunto de funciones) que le pida al usuario que seleccione una **ciudad** de la lista de ciudades disponibles en nuestro DataFrame, y un **mes** del año.
# 4. Muéstrale al usuario un gráfico que muestre las temperaturas mínimas y máximas que se registraron en la ciudad elegida durante el mes elegido.
# 5. El programa debe preguntarle al usuario si desea seguir haciendo consultas o no.
#
# **¡Mucha suerte!**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# ruta = "C:/Users/Win10/Downloads/00 - FEDE/Udemy/Python para Data Science\Día 9/11 - Proyecto del Día 9/Datos_Meteorológicos_Arg_2023.csv"
ruta = "1 Data/Datos_Meteorológicos_Arg_2023.csv"
df = pd.read_csv(ruta)
df.head()
# Out:
#       Fecha        Ciudad  Temperatura Maxima  Temperatura Minima  \
# 0  1/1/2023  Buenos Aires                  27                  18
# 1  1/1/2023       Cordoba                  35                  18
# 2  1/1/2023       Rosario                  23                  21
# 3  1/1/2023       Mendoza                  35                  21
# 4  1/1/2023       Tucuman                  36                  18
#
#    Precipitacion  Velocidad del Viento  Humedad Relativa
# 0            0.0                  22.7              68.8
# 1            0.0                  33.8              61.7
# 2            0.0                  10.6              80.0
# 3            0.0                  23.8              76.8
# 4           17.2                  25.7              54.9

# %%
df['Fecha'] = pd.to_datetime(df['Fecha'], format='%d/%m/%Y')
df.head()
# Out:
#        Fecha        Ciudad  Temperatura Maxima  Temperatura Minima  \
# 0 2023-01-01  Buenos Aires                  27                  18
# 1 2023-01-01       Cordoba                  35                  18
# 2 2023-01-01       Rosario                  23                  21
# 3 2023-01-01       Mendoza                  35                  21
# 4 2023-01-01       Tucuman                  36                  18
#
#    Precipitacion  Velocidad del Viento  Humedad Relativa
# 0            0.0                  22.7              68.8
# 1            0.0                  33.8              61.7
# 2            0.0                  10.6              80.0
# 3            0.0                  23.8              76.8
# 4           17.2                  25.7              54.9

# %%
lista_ciudades = []

for c in df['Ciudad']:
    if c not in lista_ciudades:
        lista_ciudades.append(c)

lista_ciudades
# Out:
# ['Buenos Aires', 'Cordoba', 'Rosario', 'Mendoza', 'Tucuman']

# %%
dict_meses = {
    1: 'Enero',
    2: 'Febrero',
    3: 'Marzo',
    4: 'Abril',
    5: 'Mayo',
    6: 'Junio',
    7: 'Julio',
    8: 'Agosto',
    9: 'Septiembre',
    10: 'Octubre',
    11: 'Noviembre',
    12: 'Diciembre'
}

# %%
def consultar_temperaturas():
    while True:
        # Debug
        print("\nCiudades disponibles: \n", lista_ciudades)
        print("\nMeses disponibles: \n", dict_meses)
        
        # solicitar la ciudad        
        ciudad_elegida = input("Elija la ciudad de la lista: ").title()
        
        # Solicitar el mes
        mes_elegido = int(input("Elija un número de mes (por ej. Enero = 1): "))
        
        # validar los inputs
        if ciudad_elegida not in lista_ciudades or mes_elegido not in range(1, 13):
            print("Ciudad o mes no válidos. Inténtale nuevamente.")
            continue
        
        # Crear el datafreme filtrado
        datos_ciudad_mes = df[(df['Ciudad'] == ciudad_elegida) & (df['Fecha'].dt.month == mes_elegido)]
        
        # Debug
        print("\nDatos Ciudad Mes: \n", datos_ciudad_mes)
        
        # Graficamos las temperaturas del dataframe
        plt.figure(figsize=(10, 6))
        plt.plot(datos_ciudad_mes['Fecha'], datos_ciudad_mes['Temperatura Maxima'], label="Maxima", color="red")
        plt.plot(datos_ciudad_mes['Fecha'], datos_ciudad_mes['Temperatura Minima'], label="Minima", color="blue")        
        
        # Agregado para indicar temperatura maxima y temperatura minima en grafico de lineas
        for i, row in datos_ciudad_mes.iterrows():
            # Debug
            print("\n", "******************")
            print("\n", i)
            print("\n", row)
            plt.text(row['Fecha'], row['Temperatura Maxima'], str(row['Temperatura Maxima']), ha='center', va='bottom')
            plt.text(row['Fecha'], row['Temperatura Minima'], str(row['Temperatura Minima']), ha='center', va='top')
        # Cerrar
                        
        plt.title(f"Temperaturas en {ciudad_elegida} durante el mes de {dict_meses[mes_elegido]}")
        plt.xlabel("Fecha")
        plt.ylabel("Temperaturas")
        plt.legend()
        plt.xticks(rotation=45)
        plt.grid()
        plt.show()

        # Preguntar al usuario si quiere continuar
        otra_consulta = input("¿Deseas continuar consultando? (s/n): ")
        if otra_consulta.lower() != 's':
            break

# %%
consultar_temperaturas()
# Out:
# Ciudades disponibles:
#  ['Buenos Aires', 'Cordoba', 'Rosario', 'Mendoza', 'Tucuman']
#
# Meses disponibles:
#  {1: 'Enero', 2: 'Febrero', 3: 'Marzo', 4: 'Abril', 5: 'Mayo', 6: 'Junio', 7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'}
#
# Datos Ciudad Mes:
#           Fecha   Ciudad  Temperatura Maxima  Temperatura Minima  \
# 156 2023-02-01  Cordoba                  33                  22
# 161 2023-02-02  Cordoba                  36                  20
# 166 2023-02-03  Cordoba                  25                  16
# 171 2023-02-04  Cordoba                  34                  16
# 176 2023-02-05  Cordoba                  24                  15
# 181 2023-02-06  Cordoba                  25                  15
# 186 2023-02-07  Cordoba                  35                  15
# 191 2023-02-08  Cordoba                  30                  21
# 196 2023-02-09  Cordoba                  26                  20
# 201 2023-02-10  Cordoba                  34                  17
# 206 2023-02-11  Cordoba                  36                  16
# 211 2023-02-12  Cordoba                  26                  20
# 216 2023-02-13  Cordoba                  22                  19
# 221 2023-02-14  Cordoba                  23                  21
# 226 2023-02-15  Cordoba                  35                  22
# 231 2023-02-16  Cordoba                  34                  17
# 236 2023-02-17  Cordoba                  26                  20
# 241 2023-02-18  Cordoba                  21                  19
# 246 2023-02-19  Cordoba                  36                  17
# 251 2023-02-20  Cordoba                  24                  18
# 256 2023-02-21  Cordoba                  32                  21
# 261 2023-02-22  Cordoba                  24                  19
# 266 2023-02-23  Cordoba                  23                  18
# 271 2023-02-24  Cordoba                  21                  19
# 276 2023-02-25  Cordoba                  36                  18
# 281 2023-02-26  Cordoba                  32                  15
# 286 2023-02-27  Cordoba                  24                  17
# 291 2023-02-28  Cordoba                  33                  17
#
#      Precipitacion  Velocidad del Viento  Humedad Relativa
# 156           39.6                  14.2              43.6
# 161            8.3                  32.0              40.6
# 166            0.0                  27.8              30.6
# 171            0.0                  24.1              34.1
# 176            0.0                  31.1              55.1
# 181            0.0                  20.6              37.2
# 186          108.7                  26.6              81.1
# 191            0.0                  10.7              68.0
# 196            0.0                  31.6              85.5
# 201           11.8                  11.2              79.0
# 206            0.0                  18.3              40.2
# 211            0.0                  22.9              32.1
# 216            0.0                  36.0              47.7
# 221            5.3                  19.2              63.5
# 226            0.0                  31.2              76.0
# 231            0.0                  15.0              63.4
# 236            0.0                  11.5              36.1
# 241            0.0                  35.1              59.0
# 246           85.5                  11.7              47.5
# 251            0.0                  11.4              41.9
# 256            0.0                  25.0              72.1
# 261            0.0                  27.7              73.3
# 266            0.0                  37.6              54.7
# 271            0.0                  19.2              82.5
# 276           91.6                  26.9              57.4
# 281            0.0                  39.5              38.6
# 286            0.0                  34.2              85.6
# 291            0.0                  28.5              53.1
#
#  ******************
#
#  156
#
#  Fecha                   2023-02-01 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       33
# Temperatura Minima                       22
# Precipitacion                          39.6
# Velocidad del Viento                   14.2
# Humedad Relativa                       43.6
# Name: 156, dtype: object
#
#  ******************
#
#  161
#
#  Fecha                   2023-02-02 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       36
# Temperatura Minima                       20
# Precipitacion                           8.3
# Velocidad del Viento                   32.0
# Humedad Relativa                       40.6
# Name: 161, dtype: object
#
#  ******************
#
#  166
#
#  Fecha                   2023-02-03 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       25
# Temperatura Minima                       16
# Precipitacion                           0.0
# Velocidad del Viento                   27.8
# Humedad Relativa                       30.6
# Name: 166, dtype: object
#
#  ******************
#
#  171
#
#  Fecha                   2023-02-04 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       34
# Temperatura Minima                       16
# Precipitacion                           0.0
# Velocidad del Viento                   24.1
# Humedad Relativa                       34.1
# Name: 171, dtype: object
#
#  ******************
#
#  176
#
#  Fecha                   2023-02-05 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       24
# Temperatura Minima                       15
# Precipitacion                           0.0
# Velocidad del Viento                   31.1
# Humedad Relativa                       55.1
# Name: 176, dtype: object
#
#  ******************
#
#  181
#
#  Fecha                   2023-02-06 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       25
# Temperatura Minima                       15
# Precipitacion                           0.0
# Velocidad del Viento                   20.6
# Humedad Relativa                       37.2
# Name: 181, dtype: object
#
#  ******************
#
#  186
#
#  Fecha                   2023-02-07 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       35
# Temperatura Minima                       15
# Precipitacion                         108.7
# Velocidad del Viento                   26.6
# Humedad Relativa                       81.1
# Name: 186, dtype: object
#
#  ******************
#
#  191
#
#  Fecha                   2023-02-08 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       30
# Temperatura Minima                       21
# Precipitacion                           0.0
# Velocidad del Viento                   10.7
# Humedad Relativa                       68.0
# Name: 191, dtype: object
#
#  ******************
#
#  196
#
#  Fecha                   2023-02-09 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       26
# Temperatura Minima                       20
# Precipitacion                           0.0
# Velocidad del Viento                   31.6
# Humedad Relativa                       85.5
# Name: 196, dtype: object
#
#  ******************
#
#  201
#
#  Fecha                   2023-02-10 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       34
# Temperatura Minima                       17
# Precipitacion                          11.8
# Velocidad del Viento                   11.2
# Humedad Relativa                       79.0
# Name: 201, dtype: object
#
#  ******************
#
#  206
#
#  Fecha                   2023-02-11 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       36
# Temperatura Minima                       16
# Precipitacion                           0.0
# Velocidad del Viento                   18.3
# Humedad Relativa                       40.2
# Name: 206, dtype: object
#
#  ******************
#
#  211
#
#  Fecha                   2023-02-12 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       26
# Temperatura Minima                       20
# Precipitacion                           0.0
# Velocidad del Viento                   22.9
# Humedad Relativa                       32.1
# Name: 211, dtype: object
#
#  ******************
#
#  216
#
#  Fecha                   2023-02-13 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       22
# Temperatura Minima                       19
# Precipitacion                           0.0
# Velocidad del Viento                   36.0
# Humedad Relativa                       47.7
# Name: 216, dtype: object
#
#  ******************
#
#  221
#
#  Fecha                   2023-02-14 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       23
# Temperatura Minima                       21
# Precipitacion                           5.3
# Velocidad del Viento                   19.2
# Humedad Relativa                       63.5
# Name: 221, dtype: object
#
#  ******************
#
#  226
#
#  Fecha                   2023-02-15 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       35
# Temperatura Minima                       22
# Precipitacion                           0.0
# Velocidad del Viento                   31.2
# Humedad Relativa                       76.0
# Name: 226, dtype: object
#
#  ******************
#
#  231
#
#  Fecha                   2023-02-16 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       34
# Temperatura Minima                       17
# Precipitacion                           0.0
# Velocidad del Viento                   15.0
# Humedad Relativa                       63.4
# Name: 231, dtype: object
#
#  ******************
#
#  236
#
#  Fecha                   2023-02-17 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       26
# Temperatura Minima                       20
# Precipitacion                           0.0
# Velocidad del Viento                   11.5
# Humedad Relativa                       36.1
# Name: 236, dtype: object
#
#  ******************
#
#  241
#
#  Fecha                   2023-02-18 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       21
# Temperatura Minima                       19
# Precipitacion                           0.0
# Velocidad del Viento                   35.1
# Humedad Relativa                       59.0
# Name: 241, dtype: object
#
#  ******************
#
#  246
#
#  Fecha                   2023-02-19 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       36
# Temperatura Minima                       17
# Precipitacion                          85.5
# Velocidad del Viento                   11.7
# Humedad Relativa                       47.5
# Name: 246, dtype: object
#
#  ******************
#
#  251
#
#  Fecha                   2023-02-20 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       24
# Temperatura Minima                       18
# Precipitacion                           0.0
# Velocidad del Viento                   11.4
# Humedad Relativa                       41.9
# Name: 251, dtype: object
#
#  ******************
#
#  256
#
#  Fecha                   2023-02-21 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       32
# Temperatura Minima                       21
# Precipitacion                           0.0
# Velocidad del Viento                   25.0
# Humedad Relativa                       72.1
# Name: 256, dtype: object
#
#  ******************
#
#  261
#
#  Fecha                   2023-02-22 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       24
# Temperatura Minima                       19
# Precipitacion                           0.0
# Velocidad del Viento                   27.7
# Humedad Relativa                       73.3
# Name: 261, dtype: object
#
#  ******************
#
#  266
#
#  Fecha                   2023-02-23 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       23
# Temperatura Minima                       18
# Precipitacion                           0.0
# Velocidad del Viento                   37.6
# Humedad Relativa                       54.7
# Name: 266, dtype: object
#
#  ******************
#
#  271
#
#  Fecha                   2023-02-24 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       21
# Temperatura Minima                       19
# Precipitacion                           0.0
# Velocidad del Viento                   19.2
# Humedad Relativa                       82.5
# Name: 271, dtype: object
#
#  ******************
#
#  276
#
#  Fecha                   2023-02-25 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       36
# Temperatura Minima                       18
# Precipitacion                          91.6
# Velocidad del Viento                   26.9
# Humedad Relativa                       57.4
# Name: 276, dtype: object
#
#  ******************
#
#  281
#
#  Fecha                   2023-02-26 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       32
# Temperatura Minima                       15
# Precipitacion                           0.0
# Velocidad del Viento                   39.5
# Humedad Relativa                       38.6
# Name: 281, dtype: object
#
#  ******************
#
#  286
#
#  Fecha                   2023-02-27 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       24
# Temperatura Minima                       17
# Precipitacion                           0.0
# Velocidad del Viento                   34.2
# Humedad Relativa                       85.6
# Name: 286, dtype: object
#
#  ******************
#
#  291
#
#  Fecha                   2023-02-28 00:00:00
# Ciudad                              Cordoba
# Temperatura Maxima                       33
# Temperatura Minima                       17
# Precipitacion                           0.0
# Velocidad del Viento                   28.5
# Humedad Relativa                       53.1
# Name: 291, dtype: object
